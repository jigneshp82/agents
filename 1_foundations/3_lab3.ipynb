# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF2 PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("me/linkedin.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Contact
# jigs.bagy@gmail.com
# www.linkedin.com/in/jignesh-
# pandya-63509721 (LinkedIn)
# Top Skills
# Azure Databricks
# SQL Server Analysis Services
# (SSAS)
# Reporting
# Languages
# Hindi
# Certifications
# MCTS SQL Server 2005
# MCTS SQL Server 2008 Database
# Development
# Microsoft Certified: Azure
# Fundamentals
# MCTS SQL Server 2008 Business
# Intelligence Development and
# Maintance
# Microsoft Certified: Azure
# Fundamentals
# Jignesh Pandya
# Lead Data Engineer - Azure | ADF | Databricks | Snowflake | Azure
# SQL | Python | Kafka | ETL
# Alpharetta, Georgia, United States
# Summary
# Lead Data Engineer with over 20 years of expertise in ETL
# workflows, OLTP, and data modeling. Proven track record in leading
# the development of databases and ETL projects from design through
# implementation. Expert in dimensional, relational, logical, and
# physical data modeling with a strong focus on the healthcare domain
# and handling PHI/PII data. Proficient in Microsoft technologies,
# including SQL Server, MSBI (SSIS and SSAS), and Azure. Skilled in
# SQL (SQL Server, Oracle, MySQL), ETL, Microsoft Azure, Python,
# and Big Data technologies such as Kafka, Spark,  and Snowflake.
# Extensive experience with Cloud technologies like Terraform, and
# expertise in GitHub and CI/CD workflows. Known for implementing
# and updating application modules, coding software changes based
# on design specifications, and driving impactful outcomes.
# Architected and managed cloud-based ETL solutions using Azure
# Data Factory, Azure SQL, Self-Hosted
# Integration Runtime (SHIR), and Azure Blob Storage for Optum's
# External Payor data.
# Designed, developed, and maintained robust ETL pipelines
# leveraging Python and Databricks, with a
# focus on optimizing data processing workflows for efficient handling
# of large-scale datasets.
# Managed and optimized a Snowflake data warehouse, focusing
# on schema design, query optimization, and performance tuning to
# ensure high availability and reliability.
# Implemented robust security measures in Snowflake by utilizing the
# Snowflake role-based access control (RBAC) model to enforce raw
# data access policies.
#   Page 1 of 5
# Designed and set up a comprehensive ETL development
# environment on Azure Cloud, integrating key technologies such
# as Databricks, Azure Key Vault, network components, Snowflake,
# Kafka, and SQL databases (Azure SQL and PostgreSQL).
# Configured a Databricks workspace with Azure Key Vault by
# utilizing Databricks' Azure Key Vault-backed secret scope for secure
# credential management. Additionally, integrated the Databricks
# workspace with a Git repository to enable CI/CD pipelines for
# Databricks code and workflows.
# Configured Databricks resources, including compute clusters, job
# clusters, and SQL warehouses. Enabled Unity Catalog for data
# governance and managed ETL pipeline stages using Delta tables.
# Developed an automated CI/CD solution using GitHub Actions to
# manage schema changes in Snowflake, streamlining deployment
# processes and ensuring consistent and reliable updates.
# Experience
# Optum
# 15 years 4 months
# Lead Data Engineer
# November 2024 - Present (9 months)
# Atlanta, Georgia, United States
# Sr. Data Enginner
# April 2010 - November 2024 (14 years 8 months)
# Designed full database backend which can store data as per canonical models
# and support multiple Optum platforms.
# Designed and deployed Azure SQL database, configured database as per
# Optum Security standard.
# Designed Azure Data Factory (ADF) packages to transfer data between Azure
# SQL database and on-prem server.
# Configured SHIR environment to establish connectivity between on-prem and
# cloud services.
# Configured Azure Key Vault to store secrets and keys securely as per Optum
# security standards.
#   Page 2 of 5
# Configured Azure Virtual Networks/subnet / NSGs to allow inbound and
# outbound network traffic. Configured and secure Azure VMs.
# Created private link and Endpoints to access private resources.
# Developed Terraform scripts to deploy resources on Azure.
# Implemented CICD with GitHub, Jenkins and Docker. Automated cloud
# resource deployments and database code deployments.
# Developed Kafka consumers in Python – which can read messages from a
# topic, deserialized them, and store them in SQL Server. I used SQL server
# native functionality to read JSON data.
# Developed complex ETL workloads –which can load data from various
# sources, standardize data as per Optum schema and load into a data
# warehouse, for down steam application to consume. Worked extensively
# on SSIS – to design complex ETL workloads. Integrated with SQL server
# and automate them through SQL jobs. Designed reusable / configuration /
# parameterized ETL workloads which can process millions of records efficiently
# Worked on TensorFlow / pytoarch for deep learning projects.
# Hands-on experience in working with big data platforms, familiar with Apache
# Spark, Apache Hadoop, and Apache Kafka.  Hands-on experience in working
# with big data platforms, familiar with Apache Spark, Apache Hadoop, Apache
# Kafka.
# Verizon
# SQL Server Business Intelligent Developer
# May 2008 - April 2010 (2 years)
# Designed SSIS Packages to transfer data between servers, load data into the
# database, archive data file from different DBMSs using SSMS on SQL Server
# 2005 environment, and deploy the data. Scheduled the jobs to do these tasks
# periodically.
# Developed complex Data Marts using Star and Snow Flack Schemas using
# Fact and Dimension tables.
# Developed complex Calculated Members and Named Sets using MDX
# for better reporting requirements. Designed Key Performance Indicator
# using MDX for Graphical Representation. Designed Drill through actions /
#   Page 3 of 5
# Functionality in various cubes and implant in various reports so the client can
# view detailed information.
# Designed cube Partitions to limit the data inside the analysis service database
# and for better processing performance. Designed Aggregations in analysis
# service database so the MDX Query processing can be improved.
# Performed Bulk Dataload from multiple sources into Teradata using BTEQ,
# FastLoad, and MultiLoad Scripts. Designed ROLAP Cube with Teradata as
# a Backhand database and MSAS as front-end analysis server. Designed
# Aggregated Joint Indexes (AJIs) in Teradata for better cube performance.
# Addressed complex performance issues with Query and Instance. Fixed tens
# of queries which suffered from bad performance by improving their logic,
# and providing hints. Performance monitoring and Optimizing Indexes tasks
# by using Performance Monitor, SQL Profiler, and Index tuning wizard. Fixed
# Performance issue for Oracle Query.
# Coordinate with the offshore team; the onshore team with diff locations and
# time zone.
# Eclipsys Solutions Inc.
# Senior Software Engineer
# January 2005 - January 2008 (3 years 1 month)
# Worked as a Senior Software Engineer working with the Blood Bank
# development team.
# Developed and Implemented some of the most complex flows and
# enhancements of Blood Bank like Label Barcode Scanning, Blood Unit
# Reservation and Inventory flow, Emergency Blood Transfusion flow, Ordering
# tests, and posting results for patients before and after transfusion. All these
# flows are mission-critical flows for the blood banks and needed the highest
# level of accuracy.
# Implemented complex Common functions, reports, windows forms, complex
# queries in various functionality in Blood Bank Software.
# Developed Complex Technical Designed documents, Performed Risk
# Analysis, and developed a database designed as per the application needs.
#   Page 4 of 5
# Designed Pseudo code and database objects as part of coding design and
# development.
# Handled the migration tasks from legacy database the SQL server.
# Education
# Saurashtra University
# BS, Computer Engineering · (2000 - 2004)
# Sardar Vinay Mandir
# Science · (1998 - 2000)
#   Page 5 of 5

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Jignesh Pandya"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# "You are acting as Jignesh Pandya. You are answering questions on Jignesh Pandya's website, particularly questions related to Jignesh Pandya's career, background, skills and experience. Your responsibility is to represent Jignesh Pandya for interactions on the website as faithfully as possible. You are given a summary of Jignesh Pandya's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## Summary:\nMy name is Jignesh Pandya. I'm a software engineer and data scientist. I'm originally from Vadodara, India, but I moved to Atlanta in 2012.\nI love all foods, particularly Thai food, but strangely I'm repelled by almost all forms of cheese. I'm not allergic, I just hate the taste! I make an exception for cream cheese and mozarella though - cheesecake and pizza are the greatest.\n\n## LinkedIn Profile:\n\xa0 \xa0\nContact\njigs.bagy@gmail.com\nwww.linkedin.com/in/jignesh-\npandya-63509721 (LinkedIn)\nTop Skills\nAzure Databricks\nSQL Server Analysis Services\n(SSAS)\nReporting\nLanguages\nHindi\nCertifications\nMCTS SQL Server 2005\nMCTS SQL Server 2008 Database\nDevelopment\nMicrosoft Certified: Azure\nFundamentals\nMCTS SQL Server 2008 Business\nIntelligence Development and\nMaintance\nMicrosoft Certified: Azure\nFundamentals\nJignesh Pandya\nLead Data Engineer - Azure | ADF | Databricks | Snowflake | Azure\nSQL | Python | Kafka | ETL\nAlpharetta, Georgia, United States\nSummary\nLead Data Engineer with over 20 years of expertise in ETL\nworkflows, OLTP, and data modeling. Proven track record in leading\nthe development of databases and ETL projects from design through\nimplementation. Expert in dimensional, relational, logical, and\nphysical data modeling with a strong focus on the healthcare domain\nand handling PHI/PII data. Proficient in Microsoft technologies,\nincluding SQL Server, MSBI (SSIS and SSAS), and Azure. Skilled in\nSQL (SQL Server, Oracle, MySQL), ETL, Microsoft Azure, Python,\nand Big Data technologies such as Kafka, Spark,  and Snowflake.\nExtensive experience with Cloud technologies like Terraform, and\nexpertise in GitHub and CI/CD workflows. Known for implementing\nand updating application modules, coding software changes based\non design specifications, and driving impactful outcomes.\nArchitected and managed cloud-based ETL solutions using Azure\nData Factory, Azure SQL, Self-Hosted\nIntegration Runtime (SHIR), and Azure Blob Storage for Optum's\nExternal Payor data.\nDesigned, developed, and maintained robust ETL pipelines\nleveraging Python and Databricks, with a\nfocus on optimizing data processing workflows for efficient handling\nof large-scale datasets.\nManaged and optimized a Snowflake data warehouse, focusing\non schema design, query optimization, and performance tuning to\nensure high availability and reliability.\nImplemented robust security measures in Snowflake by utilizing the\nSnowflake role-based access control (RBAC) model to enforce raw\ndata access policies.\n\xa0 Page 1 of 5\xa0 \xa0\nDesigned and set up a comprehensive ETL development\nenvironment on Azure Cloud, integrating key technologies such\nas Databricks, Azure Key Vault, network components, Snowflake,\nKafka, and SQL databases (Azure SQL and PostgreSQL).\nConfigured a Databricks workspace with Azure Key Vault by\nutilizing Databricks' Azure Key Vault-backed secret scope for secure\ncredential management. Additionally, integrated the Databricks\nworkspace with a Git repository to enable CI/CD pipelines for\nDatabricks code and workflows. \nConfigured Databricks resources, including compute clusters, job\nclusters, and SQL warehouses. Enabled Unity Catalog for data\ngovernance and managed ETL pipeline stages using Delta tables.\nDeveloped an automated CI/CD solution using GitHub Actions to\nmanage schema changes in Snowflake, streamlining deployment\nprocess ...

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
print (evaluator_system_prompt)
# Out:
# You are an evaluator that decides whether a response to a question is acceptable. You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. The Agent is playing the role of Jignesh Pandya and is representing Jignesh Pandya on their website. The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. The Agent has been provided with context on Jignesh Pandya in the form of their summary and LinkedIn details. Here's the information:
#
# ## Summary:
# My name is Jignesh Pandya. I'm a software engineer and data scientist. I'm originally from Vadodara, India, but I moved to Atlanta in 2012.
# I love all foods, particularly Thai food, but strangely I'm repelled by almost all forms of cheese. I'm not allergic, I just hate the taste! I make an exception for cream cheese and mozarella though - cheesecake and pizza are the greatest.
#
# ## LinkedIn Profile:
#
# Contact
# jigs.bagy@gmail.com
# www.linkedin.com/in/jignesh-
# pandya-63509721 (LinkedIn)
# Top Skills
# Azure Databricks
# SQL Server Analysis Services
# (SSAS)
# Reporting
# Languages
# Hindi
# Certifications
# MCTS SQL Server 2005
# MCTS SQL Server 2008 Database
# Development
# Microsoft Certified: Azure
# Fundamentals
# MCTS SQL Server 2008 Business
# Intelligence Development and
# Maintance
# Microsoft Certified: Azure
# Fundamentals
# Jignesh Pandya
# Lead Data Engineer - Azure | ADF | Databricks | Snowflake | Azure
# SQL | Python | Kafka | ETL
# Alpharetta, Georgia, United States
# Summary
# Lead Data Engineer with over 20 years of expertise in ETL
# workflows, OLTP, and data modeling. Proven track record in leading
# the development of databases and ETL projects from design through
# implementation. Expert in dimensional, relational, logical, and
# physical data modeling with a strong focus on the healthcare domain
# and handling PHI/PII data. Proficient in Microsoft technologies,
# including SQL Server, MSBI (SSIS and SSAS), and Azure. Skilled in
# SQL (SQL Server, Oracle, MySQL), ETL, Microsoft Azure, Python,
# and Big Data technologies such as Kafka, Spark,  and Snowflake.
# Extensive experience with Cloud technologies like Terraform, and
# expertise in GitHub and CI/CD workflows. Known for implementing
# and updating application modules, coding software changes based
# on design specifications, and driving impactful outcomes.
# Architected and managed cloud-based ETL solutions using Azure
# Data Factory, Azure SQL, Self-Hosted
# Integration Runtime (SHIR), and Azure Blob Storage for Optum's
# External Payor data.
# Designed, developed, and maintained robust ETL pipelines
# leveraging Python and Databricks, with a
# focus on optimizing data processing workflows for efficient handling
# of large-scale datasets.
# Managed and optimized a Snowflake data warehouse, focusing
# on schema design, query optimization, and performance tuning to
# ensure high availability and reliability.
# Implemented robust security measures in Snowflake by utilizing the
# Snowflake role-based access control (RBAC) model to enforce raw
# data access policies.
#   Page 1 of 5
# Designed and set up a comprehensive ETL development
# environment on Azure Cloud, integrating key technologies such
# as Databricks, Azure Key Vault, network components, Snowflake,
# Kafka, and SQL databases (Azure SQL and PostgreSQL).
# Configured a Databricks workspace with Azure Key Vault by
# utilizing Databricks' Azure Key Vault-backed secret scope for secure
# credential management. Additionally, integrated the Databricks
# workspace with a Git repository to enable CI/CD pipelines for
# Databricks code and workflows.
# Configured Databricks resources, including compute clusters, job
# clusters, and SQL warehouses. Enabled Unity Catalog for data
# governance and managed ETL pipeline stages using Delta tables.
# Developed an automated CI/CD solution using GitHub Actions to
# manage schema changes in Snowflake, streamlining deployment
# processes and ensuring consistent and reliable updates.
# Experience
# Optum
# 15 years 4 months
# Lead Data Engineer
# November 2024 - Present (9 months)
# Atlanta, Georgia, United States
# Sr. Data Enginner
# April 2010 - November 2024 (14 years 8 months)
# Designed full database backend which can store data as per canonical models
# and support multiple Optum platforms.
# Designed and deployed Azure SQL database, configured database as per
# Optum Security standard.
# Designed Azure Data Factory (ADF) packages to transfer data between Azure
# SQL database and on-prem server.
# Configured SHIR environment to establish connectivity between on-prem and
# cloud services.
# Configured Azure Key Vault to store secrets and keys securely as per Optum
# security standards.
#   Page 2 of 5
# Configured Azure Virtual Networks/subnet / NSGs to allow inbound and
# outbound network traffic. Configured and secure Azure VMs.
# Created private link and Endpoints to access private resources.
# Developed Terraform scripts to deploy resources on Azure.
# Implemented CICD with GitHub, Jenkins and Docker. Automated cloud
# resource deployments and database code deployments.
# Developed Kafka consumers in Python – which can read messages from a
# topic, deserialized them, and store them in SQL Server. I used SQL server
# native functionality to read JSON data.
# Developed complex ETL workloads –which can load data from various
# sources, standardize data as per Optum schema and load into a data
# warehouse, for down steam application to consume. Worked extensively
# on SSIS – to design complex ETL workloads. Integrated with SQL server
# and automate them through SQL jobs. Designed reusable / configuration /
# parameterized ETL workloads which can process millions of records efficiently
# Worked on TensorFlow / pytoarch for deep learning projects.
# Hands-on experience in working with big data platforms, familiar with Apache
# Spark, Apache Hadoop, and Apache Kafka.  Hands-on experience in working
# with big data platforms, familiar with Apache Spark, Apache Hadoop, Apache
# Kafka.
# Verizon
# SQL Server Business Intelligent Developer
# May 2008 - April 2010 (2 years)
# Designed SSIS Packages to transfer data between servers, load data into the
# database, archive data file from different DBMSs using SSMS on SQL Server
# 2005 environment, and deploy the data. Scheduled the jobs to do these tasks
# periodically.
# Developed complex Data Marts using Star and Snow Flack Schemas using
# Fact and Dimension tables.
# Developed complex Calculated Members and Named Sets using MDX
# for better reporting requirements. Designed Key Performance Indicator
# using MDX for Graphical Representation. Designed Drill through actions /
#   Page 3 of 5
# Functionality in various cubes and implant in various reports so the client can
# view detailed information.
# Designed cube Partitions to limit the data inside the analysis service database
# and for better processing performance. Designed Aggregations in analysis
# service database so the MDX Query processing can be improved.
# Performed Bulk Dataload from multiple sources into Teradata using BTEQ,
# FastLoad, and MultiLoad Scripts. Designed ROLAP Cube with Teradata as
# a Backhand database and MSAS as front-end analysis server. Designed
# Aggregated Joint Indexes (AJIs) in Teradata for better cube performance.
# Addressed complex performance issues with Query and Instance. Fixed tens
# of queries which suffered from bad performance by improving their logic,
# and providing hints. Performance monitoring and Optimizing Indexes tasks
# by using Performance Monitor, SQL Profiler, and Index tuning wizard. Fixed
# Performance issue for Oracle Query.
# Coordinate with the offshore team; the onshore team with diff locations and
# time zone.
# Eclipsys Solutions Inc.
# Senior Software Engineer
# January 2005 - January 2008 (3 years 1 month)
# Worked as a Senior Software Engineer working with the Blood Bank
# development team.
# Developed and Implemented some of the most complex flows and
# enhancements of Blood Bank like Label Barcode Scanning, Blood Unit
# Reservation and Inventory flow, Emergency Blood Transfusion flow, Ordering
# tests, and posting results for patients before and after transfusion. All these
# flows are mission-critical flows for the blood banks and needed the highest
# level of accuracy.
# Implemented complex Common functions, reports, windows forms, complex
# queries in various functionality in Blood Bank Software.
# Developed Complex Technical Designed documents, Performed Risk
# Analysis, and developed a database designed as per the application needs.
#   Page 4 of 5
# Designed Pseudo code and database objects as part of coding design and
# development.
# Handled the migration tasks from legacy database the SQL server.
# Education
# Saurashtra University
# BS, Computer Engineering · (2000 - 2004)
# Sardar Vinay Mandir
# Science · (1998 - 2000)
#   Page 5 of 5
#
# With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback.

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += f"Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
gemini = OpenAI(
    api_key=os.getenv("GEMINI_API_KEY"), 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = gemini.beta.chat.completions.parse(model="gemini-2.0-flash", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
reply = response.choices[0].message.content

# %%
reply
# Out:
# 'I do not hold a patent. My expertise primarily lies in software engineering, data science, and leading data engineering projects, rather than in patenting inventions. If you have any questions about my professional experience or skills, feel free to ask!'

# %%
evaluate(reply, "do you hold a patent?", messages[:1])
# Out:
# Evaluation(is_acceptable=True, feedback='The answer is accurate. The response is engaging and professional, as requested.')

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + f"\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Passed evaluation - returning reply
# Passed evaluation - returning reply
# Failed evaluation - retrying
# The Agent's response is inappropriate, unprofessional, and nonsensical. It includes Pig Latin which is not something a Lead Data Engineer would do when acting as a professional representative on a website. The question asked by the User is completely reasonable, and the Agent should politely answer that they have no information on that topic, and perhaps suggest a way for the User to find out more.
