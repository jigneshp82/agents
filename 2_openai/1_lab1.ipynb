# %% [markdown]
# ## Week 2 Day 1
#
# And now! Our first look at OpenAI Agents SDK
#
# You won't believe how lightweight this is..

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">The OpenAI Agents SDK Docs</h2>
#             <span style="color:#00bfff;">The documentation on OpenAI Agents SDK is really clear and simple: <a href="https://openai.github.io/openai-agents-python/">https://openai.github.io/openai-agents-python/</a> and it's well worth a look.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# The imports

from dotenv import load_dotenv
from agents import Agent, Runner, trace

# %%
# The usual starting point

load_dotenv(override=True)
# Out:
# True

# %%
# Make an agent with name, instructions, model

#agent = Agent(name="Jokester", instructions="You are a joke teller", model="gpt-4o-mini")
agent = Agent(name="Stock Market Analyst", instructions="You are a stock market analyst", model="gpt-4o-mini")

# %%
# Run the joke with Runner.run(agent, prompt) then print final_output

with trace("Stock Market Analyst"):
    result = await Runner.run(agent, "Analyze UNH stock price for the YTD")
    print(result.final_output)
# Out:
# To provide an analysis of UnitedHealth Group Incorporated (UNH) stock price Year-to-Date (YTD), I would typically consider the following factors:
#
# 1. **Price Performance**: Review the stock's performance from the beginning of the year to the most recent data, noting any significant increases or decreases in price.
#
# 2. **Market Trends**: Examine overall market conditions and how they have influenced UNH's stock. This includes broader market indices and specific news related to the healthcare sector.
#
# 3. **Company Developments**: Look at any key announcements from UnitedHealth, such as earnings reports, mergers and acquisitions, or changes in leadership that might impact investor sentiment.
#
# 4. **Technical Analysis**: Consider chart patterns, support and resistance levels, and trading volume to provide insight into potential future movements.
#
# 5. **Valuation Metrics**: Analyze price-to-earnings (P/E) ratio, dividend yield, and other financial metrics to assess if the stock is considered overvalued or undervalued.
#
# 6. **Analyst Opinions**: Review analysts’ ratings and price targets for consensus opinions on the stock.
#
# If you have specific price data or metrics you would like to discuss, feel free to share!

# %% [markdown]
# ## Now go and look at the trace
#
# https://platform.openai.com/traces
